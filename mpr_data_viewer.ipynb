# %%
from galvani import BioLogic as BL
import os
import pandas as pd

directory_path = r'C:\Users\b1104371\OneDrive - Universität Salzburg\Research\Electrolyte variation\Charecterizations\SAXS\Christian_cells\cell2\data_reduced_with_mask'
os.chdir(directory_path)
mpr_file_path = r'C:\Users\b1104371\OneDrive - Universität Salzburg\Research\Electrolyte variation\Charecterizations\SAXS\Christian_cells\cell2\data_reduced_with_mask\cell2_20250206_SKJB_0pt94_1MLiTFSI_DiGlyme_100uL_1G1PS_diamond_window_with-tape_C02.mpr'

mpr = BL.MPRfile(mpr_file_path)
elec_df_temp = pd.DataFrame(mpr.data)
elec_df_temp.to_csv('electrochemtest_GCD.txt', sep = '\t')
print(elec_df_temp)
# Out:
#        flags  Ns         time/s       dq/mA.h  (Q-Qo)/mA.h  control/V/mA  \
# 0          7   0       0.000000  0.000000e+00     0.000000        0.0000
# 1          7   0       1.000000  0.000000e+00     0.000000        0.0000
# 2          7   0       2.000000  0.000000e+00     0.000000        0.0000
# 3          7   0       3.000000  0.000000e+00     0.000000        0.0000
# 4          7   0       4.000000  0.000000e+00     0.000000        0.0000
# ...      ...  ..            ...           ...          ...           ...
# 28710      5   2  142954.999568  2.181424e-04    -0.095756        0.1573
# 28711      5   2  142959.999568  2.181400e-04    -0.095537        0.1573
# 28712      5   2  142964.999569  2.181363e-04    -0.095319        0.1573
# 28713      5   2  142966.644770  7.177666e-05    -0.095248        0.1573
# 28714     69   2  142966.644970  8.724792e-09    -0.095248        0.1573
#
#           Ewe/V  I Range  Q charge/discharge/mA.h  half cycle       P/W
# ...

# %%
directory_path = r'C:\Users\b1104371\OneDrive - Universität Salzburg\EC_backup\Electrolyte_variation\After Beamtime\SKJB\20240729_satDME_200HFE'
os.chdir(directory_path)
mpr_file_path = r"C:\Users\b1104371\OneDrive - Universität Salzburg\EC_backup\Electrolyte_variation\After Beamtime\SKJB\20240729_satDME_200HFE\20240729-2503-SKJB_0pt878mg_sat_DME_200HFE_50uL_electrolyte_2GSeperator_06_CV_C04.mpr"

mpr = BL.MPRfile(mpr_file_path)
elec_df_temp = pd.DataFrame(mpr.data)
elec_df_temp.to_csv('electrochemtest_GCD.txt', sep = '\t')
print(elec_df_temp)
# Out:
#        flags         time/s  control/V     Ewe/V    <I>/mA  cycle number  \
# 0          6  418956.252382   2.236666  2.236136  0.956506           1.0
# 1         22  418957.352381   2.236116  2.235686  0.933912           1.0
# 2         22  418959.351979   2.235116  2.234707  0.907400           1.0
# 3         22  418961.351578   2.234116  2.233690  0.838901           1.0
# 4         22  418963.351477   2.233116  2.232711  0.809807           1.0
# ...      ...            ...        ...       ...       ...           ...
# 14415     22  447749.536529   2.239516  2.239096  0.043418           4.0
# 14416     22  447751.536528   2.238515  2.238131  0.038621           4.0
# 14417     22  447753.536126   2.237515  2.237085  0.033612           4.0
# 14418     22  447754.835925   2.236866  2.236484  0.028559           4.0
# 14419     70  447755.049525   2.236666  2.236270  0.026860           4.0
#
#         (Q-Qo)/C  I Range       P/W
# 0       0.000000       12  0.002139
# ...
